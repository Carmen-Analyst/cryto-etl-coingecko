# %%
import numpy as np
import pandas as pd

df = pd.read_csv("../../data/btc_exchange_rates.csv")

df["date"] = pd.to_datetime(df["date"])

df
# Out:
#                         date      price_usd      price_eur
# 0    2025-04-20 16:04:44.724   84357.124867   74176.991396
# 1    2025-04-20 17:04:34.686   84598.168647   74388.946253
# 2    2025-04-20 18:04:48.198   84563.859429   74358.777437
# 3    2025-04-20 19:04:44.699   84561.238706   74356.472980
# 4    2025-04-20 20:04:45.731   84633.096311   74419.658881
# ...                      ...            ...            ...
# 2155 2025-07-19 12:04:00.226  118387.984219  101807.747029
# 2156 2025-07-19 13:04:09.812  118278.772828  101713.830693
# 2157 2025-07-19 14:03:23.188  118217.533576  101661.167998
# 2158 2025-07-19 15:03:41.100  117786.430237  101290.440682
# 2159 2025-07-19 16:00:38.000  118163.028159  101614.296066
#
# [2160 rows x 3 columns]

# %%
price_usd = df["price_usd"]
price_eur = df["price_eur"]

# %%
usd_initial = price_usd.iloc[0]
usd_final = price_usd.iloc[-1]

eur_initial = price_eur.iloc[0]
eur_final = price_eur.iloc[-1]

# %%
usd_return = (usd_final - usd_initial) / usd_initial * 100
eur_return = (eur_final - eur_initial) / eur_initial * 100

print(f"Rendimiento acumulado BTC/USD: {usd_return:.2f}%")
print(f"Rendimiento acumulado BTC/EUR: {eur_return:.2f}%")
# Out:
# Rendimiento acumulado BTC/USD: 40.07%
# Rendimiento acumulado BTC/EUR: 36.99%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df["date"], df["price_usd"], label="BTC/USD", color="blue")
plt.plot(df["date"], df["price_eur"], label="BTC/EUR", color="orange")

plt.title("Evolución del precio de BTC en USD y EUR")
plt.xlabel("Fecha")
plt.ylabel("Precio")
plt.legend()
plt.grid(True)
plt.show()

# %%
returns_df = pd.DataFrame({
    "par": ["BTC/USD", "BTC/EUR"],
    "rendimiento (%)": [usd_return, eur_return]
})

returns_df.to_csv("../../data/btc_returns_summary.csv", index=False)
print("✅ CSV de rendimientos guardado en: ../../data/btc_returns_summary.csv")
# Out:
# ✅ CSV de rendimientos guardado en: ../../data/btc_returns_summary.csv
